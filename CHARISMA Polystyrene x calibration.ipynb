# %%
from ramanchada.classes import RamanChada, SpectrumGroup

# %%
ps_ref_file = r"\\vm-stor-51\alle\Projekte Kunststoffe\RD\MA\Öffentliche_Projekte\2020-01-07_230007_H2020-CHARISMA_barton\Python\charisma-raman-spectrum-harmonization\ramanchada\src\ramanchada\testdata\Polystyrene.spc"
ps_tar_file = rps_file = rps_file = r"\\vm-stor-51\alle\Projekte Kunststoffe\RD\MA\Öffentliche_Projekte\2020-01-07_230007_H2020-CHARISMA_barton\Python\charisma-raman-spectrum-harmonization\ramanchada\src\ramanchada\testdata\27 polystyrene.spc"

# %%
PS_ref = RamanChada(ps_ref_file)
PS_tar = RamanChada(ps_tar_file)
# Out:
# gx-y(1)
# x-y(1)

# %%
# %matplotlib notebook

# %%
PS_ref.plot()

# %%
PS_ref.x_crop(250, 3250)

# %%
PS_ref.normalize('minmax')

# %%
PS_ref.plot()

# %%
PS_ref.show_bands()

# %%
PS_tar.plot()

# %%
PS_tar.x_crop(156, 4250)

# %%
PS_tar.normalize('minmax')

# %%
PS_tar.plot()

# %%
G = SpectrumGroup([PS_ref, PS_tar])

# %%
G.data_labels=['Reference', 'Target']

# %%
G.plot()
# Out:
# <img src="data:image/png;base64,..." width="576">

# %%
ps_cal = PS_tar.make_x_calibration(PS_ref, fitmethod='vg')

# %%
ps_cal.show()
# Out:
# <img src="data:image/png;base64,..." width="465.6">

# %%
PS_tar.calibrate(ps_cal)

# %%
G.add(PS_tar)

# %%
G.data_labels
# Out:
# ['Reference', 'Target', '27 polystyrene.spc']

# %%
G.data_labels[-1] = 'x-calibrated Target'

# %%
G.plot()
# Out:
# <img src="data:image/png;base64,..." width="428">

# %%
G.plot()
# Out:
# <img src="data:image/png;base64,..." width="424">
