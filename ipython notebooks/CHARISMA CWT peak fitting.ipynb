# %% [markdown]
# # CHARISMA: Spectrum peak detection using wavelet transformation.

# %%
from ramanchada.classes import make_test_RamanChada

# %%
from scipy.signal import find_peaks_cwt

# %%
r = make_test_RamanChada()

# %% [markdown]
# #### Regular peak search for comparison

# %%
r.peaks()
r.show_bands()
# Out:
# \\vm-stor-51\alle\projekte kunststoffe\rd\ma\öffentliche_projekte\2020-01-07_230007_h2020-charisma_barton\python\charisma-raman-spectrum-harmonization\ramanchada\src\ramanchada\analysis\peaks.py:370: RuntimeWarning: overflow encountered in multiply
#   return y0 + amp * voigt_profile(x-cen, sigma, gamma)

# %% [markdown]
# #### CWT

# %%
r.peaks(cwt=True, fitmethod = 'pearson', show=False, cwt_width=20)
r.show_bands()
r.bands
# Out:
# \\vm-stor-51\alle\projekte kunststoffe\rd\ma\öffentliche_projekte\2020-01-07_230007_h2020-charisma_barton\python\charisma-raman-spectrum-harmonization\ramanchada\src\ramanchada\analysis\peaks.py:74: PeakPropertyWarning: some peaks have a prominence of 0
#   w, _, _, _ = peak_widths(s, p, rel_height=rel_height)
# \\vm-stor-51\alle\projekte kunststoffe\rd\ma\öffentliche_projekte\2020-01-07_230007_h2020-charisma_barton\python\charisma-raman-spectrum-harmonization\ramanchada\src\ramanchada\analysis\peaks.py:74: PeakPropertyWarning: some peaks have a width of 0
#   w, _, _, _ = peak_widths(s, p, rel_height=rel_height)
# C:\Users\barton\.conda\envs\ramanchada-dev\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
#        position      intensity  pearson fitted position  pearson fitted FWHM  \
# ...

# %%
r.peaks(cwt=True, fitmethod = 'pearson', show=False, cwt_width=20)
r.show_bands()
r.bands
# Out:
# \\vm-stor-51\alle\projekte kunststoffe\rd\ma\öffentliche_projekte\2020-01-07_230007_h2020-charisma_barton\python\charisma-raman-spectrum-harmonization\ramanchada\src\ramanchada\analysis\peaks.py:74: PeakPropertyWarning: some peaks have a prominence of 0
#   w, _, _, _ = peak_widths(s, p, rel_height=rel_height)
# \\vm-stor-51\alle\projekte kunststoffe\rd\ma\öffentliche_projekte\2020-01-07_230007_h2020-charisma_barton\python\charisma-raman-spectrum-harmonization\ramanchada\src\ramanchada\analysis\peaks.py:74: PeakPropertyWarning: some peaks have a width of 0
#   w, _, _, _ = peak_widths(s, p, rel_height=rel_height)
# C:\Users\barton\.conda\envs\ramanchada-dev\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
#        position      intensity  pearson fitted position  pearson fitted FWHM  \
# ...
