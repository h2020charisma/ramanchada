# %%
from chada import makeXCalFromSpec, Chada

# %% [markdown]
# The shifts between both CHADA files is calculated

# %%
makeXCalFromSpec(r"C:\Users\barton\Desktop\chada\200218-17_shifted.cha", r"C:\Users\barton\Desktop\chada\200218-17.cha", bounds=[-10.,10.])

# %% [markdown]
# Now, a copy of the unshifted CHADA is made as "C:\Users\barton\Desktop\chada\200218-17_target.cha", and loaded from disk into CHADA Cs

# %%
C = Chada(r"C:\Users\barton\Desktop\chada\200218-17_shifted.cha")

# %%
C.plot()

# %%
C.XCalFromFile(r"C:\Users\barton\Desktop\chada\200218-17_shifted.chacal")

# %%
C.plot()

# %%
C.commit("calibrated")
# Out:
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'dynamic_meta.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'transformers.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'commits.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)

# %%
import pandas as pd

# %%
pd.Series(C.transformers)
# Out:
# 0    [baselineT, [16458.367567535784, 16454.0794616...
# 1                                  [x_crop, 500, 2500]
# 2                                    [normalize, area]
# 3    [XCal, [631.638671875, 859.189453125, 1095.613...
# 4    [XCal, [633.013671875, 863.19140625, 1100.7832...
# dtype: object

# %%
from chada import ChadaGroup

# %%
G = ChadaGroup([r"C:\Users\barton\Desktop\chada\200218-17.cha", r"C:/Users/barton/Desktop/chada/200218-17_shifted.cha"])

# %%
G.plot()

# %%
G.distance()

# %%
C.rewind(-1)

# %%
pd.Series(C.transformers)
# Out:
# 0    [baselineT, [16458.367567535784, 16454.0794616...
# 1                                  [x_crop, 500, 2500]
# 2                                    [normalize, area]
# 3    [XCal, [631.638671875, 859.189453125, 1095.613...
# dtype: object

# %%
C.rewind(-1)

# %%
pd.Series(C.transformers)
# Out:
# 0    [baselineT, [16458.367567535784, 16454.0794616...
# 1                                  [x_crop, 500, 2500]
# 2                                    [normalize, area]
# dtype: object

# %%
C.plot()

# %%
C.commit('uncalibrated')
# Out:
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'dynamic_meta.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'transformers.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'commits.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)

# %%
G = ChadaGroup([r"C:\Users\barton\Desktop\chada\200218-17.cha", r"C:/Users/barton/Desktop/chada/200218-17_shifted.cha"])

# %%
G.plot()

# %%
C.rewind(0)

# %%
C.plot()

# %%
C.baseline()

# %%
C.normalize()

# %%
C.commit()
# Out:
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'dynamic_meta.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'transformers.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'commits.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)

# %%
makeXCalFromSpec(r"C:\Users\barton\Desktop\chada\200218-17_shifted.cha", r"C:\Users\barton\Desktop\chada\200218-17.cha", bounds=[-10.,10.])

# %%
C.XCalFromFile(r"C:\Users\barton\Desktop\chada\200218-17_shifted.chacal")

# %%
C.commit()
# Out:
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'dynamic_meta.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'transformers.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'commits.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)

# %%
G = ChadaGroup([r"C:\Users\barton\Desktop\chada\200218-17.cha", r"C:/Users/barton/Desktop/chada/200218-17_shifted.cha"])

# %%
G.plot()

# %%
source_file = r"C:\Users\barton\Desktop\chada\200218-17.wdf"

# %%
from chada import create

# %%
create(source_file, r"C:\Users\barton\Desktop\chada\chatest.cha")

# %%
A = Chada(r"C:/Users/barton/Desktop/chada/chatest_A.cha")
B = Chada(r"C:/Users/barton/Desktop/chada/chatest_B.cha")
C = Chada(r"C:/Users/barton/Desktop/chada/chatest_C.cha")

# %%
B.shiftX(np.linspace(0, 10, len(B.x_data)))

# %%
C.shiftX(np.linspace(5, -5, len(B.x_data)))

# %%
A.x_crop(500, 3200)
B.x_crop(500, 3200)
C.x_crop(500, 3200)

# %%
A.baseline()
B.baseline()
C.baseline()

# %%
A.commit('original')
B.commit('shifted')
C.commit('shifted')
# Out:
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'dynamic_meta.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'transformers.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'commits.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)

# %%
G = ChadaGroup([r"C:/Users/barton/Desktop/chada/chatest_A.cha", r"C:/Users/barton/Desktop/chada/chatest_B.cha", r"C:/Users/barton/Desktop/chada/chatest_C.cha"])

# %%
G.plot()

# %%
G.distance()

# %%
makeXCalFromSpec(r"C:/Users/barton/Desktop/chada/chatest_B.cha", r"C:/Users/barton/Desktop/chada/chatest_A.cha", bounds=[-15.,15.])

# %%
makeXCalFromSpec(r"C:/Users/barton/Desktop/chada/chatest_C.cha", r"C:/Users/barton/Desktop/chada/chatest_A.cha", bounds=[-15.,15.])

# %%
B.XCalFromFile(r"C:\Users\barton\Desktop\chada\chatest_B.chacal")
C.XCalFromFile(r"C:\Users\barton\Desktop\chada\chatest_C.chacal")

# %%
B.commit('calibrated')
C.commit('calibrated')
# Out:
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'dynamic_meta.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'transformers.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\barton\.conda\envs\Extended_LBF\lib\zipfile.py:1506: UserWarning: Duplicate name: 'commits.txt'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)

# %%
G = ChadaGroup([r"C:/Users/barton/Desktop/chada/chatest_A.cha", r"C:/Users/barton/Desktop/chada/chatest_B.cha", r"C:/Users/barton/Desktop/chada/chatest_C.cha"])

# %%
G.plot()

# %%
G.distance()

# %%
# %matplotlib notebook

# %%
G.plot()
# Out:
# <img src="data:," width="0">

# %%
G.plot()
# Out:
# <img src="data:image/png;base64,..." width="692">

# %%
G.plot()
# Out:
# <img src="data:," width="0">

# %%
G.plot()
# Out:
# <img src="data:image/png;base64,..." width="644.8">

# %%
G.plot()
# Out:
# <img src="data:image/png;base64,..." width="652.8">
